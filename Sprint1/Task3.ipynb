// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 10

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Создать базовый класс Invoice в C#, который будет представлять информацию о
// фактурах за поставленные товары или оказанные услуги. На основе этого класса
// разработать 2-3 производных класса, демонстрирующих принципы наследования и
// полиморфизма. В каждом из классов должны быть реализованы новые атрибуты и
// методы, а также переопределены некоторые методы базового класса для
// демонстрации полиморфизма.
// Требования к базовому классу Invoice:
// • Атрибуты: Номер фактуры (InvoiceNumber), Дата выдачи (IssueDate), Общая
// сумма (TotalAmount).
// • Методы:
// o
// o CalculateTotal(): метод для расчета общей суммы по фактуре.
// o AddLine(LineItem lineItem): метод для добавления позиции в фактуру.
// o RemoveLine(LineItem lineItem): метод для удаления позиции из
// фактуры.
// Требования к производным классам:
// 1. ТоварнаяФактура (GoodsInvoice): Должна содержать дополнительные
// атрибуты, такие как Дата поставки (SupplyDate). Метод AddLine() должен
// быть переопределен для добавления информации о дате поставки товара
// при добавлении позиции.
// 2. УслуговаяФактура (ServiceInvoice): Должна содержать дополнительные
// атрибуты, такие как Дата оказания услуги (ServiceDate).
// Метод RemoveLine() должен быть переопределен для добавления
// информации о причине аннулирования услуги при удалении позиции.
// 3. КомбинированнаяФактура (CombinedInvoice) (если требуется третий класс):
// Должна содержать дополнительные атрибуты, такие как Наличие возврата
// (ReturnAllowed). Метод CalculateTotal() должен быть переопределен для
// учета возможного возврата товара или услуги при расчете общей суммы.
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;


// Класс позиции фактуры
public class LineItem
{
    public string Name { get; set; }
    public double Price { get; set; }

    // Конструктор
    public LineItem(string name, double price)
    {
        Name = name;
        Price = price;
    }
}


// Базовый класс Invoice
public class Invoice
{
    public string InvoiceNumber { get; set; }
    public DateTime IssueDate { get; set; }
    public double TotalAmount { get; set; }

    public List<LineItem> Lines { get; set; }

    // Конструктор
    public Invoice(string invoiceNumber, DateTime issueDate)
    {
        InvoiceNumber = invoiceNumber;
        IssueDate = issueDate;
        TotalAmount = 0;
        Lines = new List<LineItem>();
    }

    public virtual void CalculateTotal()
    {
        TotalAmount = 0;

        foreach (LineItem line in Lines)
        {
            TotalAmount += line.Price;
        }

        Console.WriteLine($"Общая сумма фактуры: {TotalAmount} руб.");
    }

    public virtual void AddLine(LineItem lineItem)
    {
        Lines.Add(lineItem);

        Console.WriteLine(
            $"Добавлена позиция: {lineItem.Name}");
    }

    public virtual void RemoveLine(LineItem lineItem)
    {
        Lines.Remove(lineItem);

        Console.WriteLine(
            $"Удалена позиция: {lineItem.Name}");
    }
}


// Товарная фактура
public class GoodsInvoice : Invoice
{
    public DateTime SupplyDate { get; set; }

    // Конструктор
    public GoodsInvoice(
        string invoiceNumber,
        DateTime issueDate,
        DateTime supplyDate)
        : base(invoiceNumber, issueDate)
    {
        SupplyDate = supplyDate;
    }

    public override void AddLine(LineItem lineItem)
    {
        base.AddLine(lineItem);

        Console.WriteLine(
            $"Дата поставки товара: {SupplyDate:dd.MM.yyyy}");
    }
}


// Фактура за услуги
public class ServiceInvoice : Invoice
{
    public DateTime ServiceDate { get; set; }

    // Конструктор
    public ServiceInvoice(
        string invoiceNumber,
        DateTime issueDate,
        DateTime serviceDate)
        : base(invoiceNumber, issueDate)
    {
        ServiceDate = serviceDate;
    }

    public override void RemoveLine(LineItem lineItem)
    {
        base.RemoveLine(lineItem);

        Console.WriteLine(
            "Причина аннулирования услуги: услуга отменена.");
    }
}


// Комбинированная фактура
public class CombinedInvoice : Invoice
{
    public bool ReturnAllowed { get; set; }

    // Конструктор
    public CombinedInvoice(
        string invoiceNumber,
        DateTime issueDate,
        bool returnAllowed)
        : base(invoiceNumber, issueDate)
    {
        ReturnAllowed = returnAllowed;
    }

    public override void CalculateTotal()
    {
        base.CalculateTotal();

        if (ReturnAllowed)
        {
            Console.WriteLine(
                "Возврат товара или услуги разрешен.");
        }
        else
        {
            Console.WriteLine(
                "Возврат товара или услуги не разрешен.");
        }
    }

    // Взаимодействие объектов
    public void ShowItemFromInvoice(LineItem item)
    {
        Console.WriteLine(
            $"В фактуре №{InvoiceNumber} находится позиция '{item.Name}' " +
            $"стоимостью {item.Price} руб.");
    }
}


// Создание объектов
LineItem product = new LineItem("Ноутбук", 50000);
LineItem service = new LineItem("Настройка программы", 5000);


// Создание товарной фактуры
GoodsInvoice goodsInvoice = new GoodsInvoice(
    "G-001",
    new DateTime(2026, 9, 12),
    new DateTime(2026, 9, 15));

goodsInvoice.AddLine(product);
goodsInvoice.CalculateTotal();

Console.WriteLine();


// Создание фактуры за услуги
ServiceInvoice serviceInvoice = new ServiceInvoice(
    "S-001",
    new DateTime(2026, 9, 12),
    new DateTime(2026, 9, 16));

serviceInvoice.AddLine(service);
serviceInvoice.CalculateTotal();
serviceInvoice.RemoveLine(service);

Console.WriteLine();


// Создание комбинированной фактуры
CombinedInvoice combinedInvoice = new CombinedInvoice(
    "C-001",
    new DateTime(2026, 9, 12),
    true);

combinedInvoice.AddLine(product);
combinedInvoice.AddLine(service);
combinedInvoice.CalculateTotal();

Console.WriteLine();


// Взаимодействие объектов
combinedInvoice.ShowItemFromInvoice(product);
combinedInvoice.ShowItemFromInvoice(service);
// Out:
// Добавлена позиция: Ноутбук
// Дата поставки товара: 15.09.2026
// Общая сумма фактуры: 50000 руб.
//
// Добавлена позиция: Настройка программы
// Общая сумма фактуры: 5000 руб.
// Удалена позиция: Настройка программы
// Причина аннулирования услуги: услуга отменена.
//
// Добавлена позиция: Ноутбук
// Добавлена позиция: Настройка программы
// Общая сумма фактуры: 55000 руб.
// Возврат товара или услуги разрешен.
//
// В фактуре №C-001 находится позиция 'Ноутбук' стоимостью 50000 руб.
// В фактуре №C-001 находится позиция 'Настройка программы' стоимостью 5000 руб.
